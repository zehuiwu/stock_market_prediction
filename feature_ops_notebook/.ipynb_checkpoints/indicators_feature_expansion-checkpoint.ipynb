# %%
from ta import add_all_ta_features
import pandas as pd

# %%
df_aapl = pd.read_csv('./data/eod/AAPL.csv')
df_aapl
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2020-04-30   72.489998   73.632500   72.087502   73.449997   72.454391
# 1    2020-05-01   71.562500   74.750000   71.462502   72.267502   71.287926
# 2    2020-05-04   72.292503   73.422501   71.580002   73.290001   72.296555
# 3    2020-05-05   73.764999   75.250000   73.614998   74.389999   73.381645
# 4    2020-05-06   75.114998   75.809998   74.717499   75.157501   74.138748
# ..          ...         ...         ...         ...         ...         ...
# 500  2022-04-25  161.119995  163.169998  158.460007  162.880005  162.880005
# 501  2022-04-26  162.250000  162.339996  156.720001  156.800003  156.800003
# 502  2022-04-27  155.910004  159.789993  155.380005  156.570007  156.570007
# 503  2022-04-28  159.250000  164.520004  158.929993  163.639999  163.639999
# 504  2022-04-29  161.839996  166.199997  157.250000  157.649994  157.649994
#
#         Volume
# 0    183064000
# 1    240616800
# ...

# %%
df_aapl_added = add_all_ta_features(
    df_aapl, open="Open", high="High", low="Low", close="Close", volume="Volume", fillna=True)
df_aapl_added = df_aapl_added[20:]
# Out:
# C:\Users\KingO\anaconda3\envs\cv\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\KingO\anaconda3\envs\cv\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# C:\Users\KingO\anaconda3\envs\cv\lib\site-packages\ta\trend.py:938: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self._psar_up = pd.Series(index=self._psar.index)
# C:\Users\KingO\anaconda3\envs\cv\lib\site-packages\ta\trend.py:939: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self._psar_down = pd.Series(index=self._psar.index)

# %%
df_aapl_added.reset_index(drop=True)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2020-05-29   79.812500   80.287498   79.117500   79.485001   78.619843
# 1    2020-06-01   79.437500   80.587502   79.302498   80.462502   79.586693
# 2    2020-06-02   80.187500   80.860001   79.732498   80.834999   79.955139
# 3    2020-06-03   81.165001   81.550003   80.574997   81.279999   80.395302
# 4    2020-06-04   81.097504   81.404999   80.195000   80.580002   79.702927
# ..          ...         ...         ...         ...         ...         ...
# 480  2022-04-25  161.119995  163.169998  158.460007  162.880005  162.880005
# 481  2022-04-26  162.250000  162.339996  156.720001  156.800003  156.800003
# 482  2022-04-27  155.910004  159.789993  155.380005  156.570007  156.570007
# 483  2022-04-28  159.250000  164.520004  158.929993  163.639999  163.639999
# 484  2022-04-29  161.839996  166.199997  157.250000  157.649994  157.649994
#
# ...

# %%
symbols = ['TSLA', 'AAPL', 'AMZN', 'GOOG','NFLX', 'FB']
for symbol in symbols:
    df = pd.read_csv('./data/eod/{}.csv'.format(symbol))
    df = add_all_ta_features(
        df, open="Open", high="High", low="Low", close="Close", volume="Volume", fillna=True)
    df = df[20:]
    df = df.reset_index(drop=True)
    df.to_csv('./data/eod/{}_features.csv'.format(symbol), encoding='utf-8')
# Out:
# C:\Users\KingO\anaconda3\envs\cv\lib\site-packages\ta\trend.py:769: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# C:\Users\KingO\anaconda3\envs\cv\lib\site-packages\ta\trend.py:774: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# C:\Users\KingO\anaconda3\envs\cv\lib\site-packages\ta\trend.py:938: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self._psar_up = pd.Series(index=self._psar.index)
# C:\Users\KingO\anaconda3\envs\cv\lib\site-packages\ta\trend.py:939: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   self._psar_down = pd.Series(index=self._psar.index)
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume',
#        'volume_adi', 'volume_obv', 'volume_cmf', 'volume_fi', 'volume_em',
#        'volume_sma_em', 'volume_vpt', 'volume_vwap', 'volume_mfi',
#        'volume_nvi', 'volatility_bbm', 'volatility_bbh', 'volatility_bbl',
#        'volatility_bbw', 'volatility_bbp', 'volatility_bbhi',
#        'volatility_bbli', 'volatility_kcc', 'volatility_kch', 'volatility_kcl',
#        'volatility_kcw', 'volatility_kcp', 'volatility_kchi',
#        'volatility_kcli', 'volatility_dcl', 'volatility_dch', 'volatility_dcm',
#        'volatility_dcw', 'volatility_dcp', 'volatility_atr', 'volatility_ui',
#        'trend_macd', 'trend_macd_signal', 'trend_macd_diff', 'trend_sma_fast',
#        'trend_sma_slow', 'trend_ema_fast', 'trend_ema_slow',
#        'trend_vortex_ind_pos', 'trend_vortex_ind_neg', 'trend_vortex_ind_diff',
#        'trend_trix', 'trend_mass_index', 'trend_dpo', 'trend_kst',
# ...

# %%
df[["volatility_bbm", "volatility_bbh", "volatility_bbl"]].plot(title="Bolinger Bands (ta)")
# Out:
# <AxesSubplot:title={'center':'Bolinger Bands (ta)'}>
